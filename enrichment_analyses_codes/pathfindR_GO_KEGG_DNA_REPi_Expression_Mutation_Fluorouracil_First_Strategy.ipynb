# %%
# import packages and suppress warnings

suppressPackageStartupMessages(library(pathfindR))
suppressPackageStartupMessages(library(readxl))
suppressPackageStartupMessages(library(biomaRt))
suppressPackageStartupMessages(library(limma))
suppressPackageStartupMessages(library(ggplot2))

# %%
# define directories

pathfindR_dir = "/Volumes/Expansion/Thesis Work/Results/Transfer Learning/Drugs with same pathways/DNA_REPi/Expression_Mutation/pathfindR/GDSC_PDX_TCGA_First_Strategy/"
gdsc_dir = "/Volumes/Expansion/Thesis Work/Supplementary Files/GDSC/"
exp_dir = "/Volumes/Expansion/Thesis Work/Results/preprocessed_results2/exprs/"

# %%
# create directory for pathfindR analysis and change to that directory

dir.create(pathfindR_dir, showWarnings = FALSE)
setwd(pathfindR_dir)
getwd()
# Out:
# [1] "/Volumes/Expansion/Thesis Work/Results/Transfer Learning/Drugs with same pathways/DNA_REPi/Expression_Mutation/pathfindR/GDSC_PDX_TCGA_First_Strategy"

# %%
# read DEGs table of 5-Fluorouracil (DNA_REPi)

input_df <- read.delim(paste0(pathfindR_dir, "/GDSC_Expression_Mutation_Filtered_DEGs_Table_DNA_REPi_Fluorouracil.tsv"))
input_df <- input_df[,c("symbol","logFC","adj.P.Val")]

head(input_df, 3)
# Out:
#   symbol   logFC     adj.P.Val
# 1 LAT2     -2.029515 1.749856e-25
# 2 TRAF3IP3 -1.392800 1.379684e-24
# 3 MYO1F    -1.205930 4.865976e-24

# %%
# run pathfindR

output_df <- run_pathfindR(input_df, 
                            output_dir = paste(pathfindR_dir,"KEGG_Fluorouracil",sep="/"),
                            pin_name_path = "KEGG",
                            adj_method = "fdr",
                            enrichment_threshold = 0.05,
                            min_gset_size = 5,
                            max_gset_size = 500,
                            iterations = 25,
                            gene_sets= "KEGG")
# Out:
# ## Testing input
#
# The input looks OK
#
# ## Processing input. Converting gene symbols,
#           if necessary (and if human gene symbols provided)
#
# Number of genes provided in input: 699
#
# Number of genes in input after p-value filtering: 642
#
# pathfindR cannot handle p values < 1e-13. These were changed to 1e-13
#
#
#
# Could not find any interactions for 333 (51.87%) genes in the PIN
#
# Final number of genes in input: 309
#
# ## Performing Active Subnetwork Search and Enrichment
#
# ## Processing the enrichment results over all iterations
#
# ## Annotating involved genes and visualizing enriched terms
#
# ## Creating HTML report
#
#
#
# processing file: results.Rmd
# 1/3
# 2/3 [setup]
# 3/3
# output file: results.knit.md
# /opt/homebrew/bin/pandoc +RTS -K512m -RTS results.knit.md --to html4 --from markdown+autolink_bare_uris+tex_math_single_backslash --output pandoc141b3313a3582.html --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/latex-div.lua --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/table-classes.lua --embed-resources --standalone --variable bs3=TRUE --section-divs --template /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable theme=bootstrap --mathjax --variable 'mathjax-url=https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML' --include-in-header /var/folders/fg/9tfxwbns2z9bny6_29d9jxyc0000gn/T//RtmpKDvWDu/rmarkdown-str141b352c5b242.html
# Output created: results.html
#
#
#
# processing file: enriched_terms.Rmd
# 1/4
# 2/4 [setup]
# 3/4
# 4/4 [table]
# output file: enriched_terms.knit.md
# /opt/homebrew/bin/pandoc +RTS -K512m -RTS enriched_terms.knit.md --to html4 --from markdown+autolink_bare_uris+tex_math_single_backslash --output pandoc141b3adde023.html --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/latex-div.lua --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/table-classes.lua --embed-resources --standalone --variable bs3=TRUE --section-divs --template /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable theme=bootstrap --mathjax --variable 'mathjax-url=https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML' --include-in-header /var/folders/fg/9tfxwbns2z9bny6_29d9jxyc0000gn/T//RtmpKDvWDu/rmarkdown-str141b37beb254c.html
# Output created: enriched_terms.html
#
#
#
# processing file: conversion_table.Rmd
# 1/6
# 2/6 [setup]
# 3/6
# 4/6 [converted_tbl, table1]
# 5/6
# 6/6 [gene_wo_interaction, table2]
# output file: conversion_table.knit.md
# /opt/homebrew/bin/pandoc +RTS -K512m -RTS conversion_table.knit.md --to html4 --from markdown+autolink_bare_uris+tex_math_single_backslash --output pandoc141b35db5221d.html --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/latex-div.lua --lua-filter /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmarkdown/lua/table-classes.lua --embed-resources --standalone --variable bs3=TRUE --section-divs --template /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/library/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable theme=bootstrap --mathjax --variable 'mathjax-url=https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML' --include-in-header /var/folders/fg/9tfxwbns2z9bny6_29d9jxyc0000gn/T//RtmpKDvWDu/rmarkdown-str141b370ba66d4.html
# Output created: conversion_table.html
#
# Plotting the enrichment bubble chart
#
# Found 199 enriched terms
#
#
#
# You may run:
#
#
# - cluster_enriched_terms() for clustering enriched terms
#
#
# - visualize_terms() for visualizing enriched term diagrams
# plot without title

# %%
# show pathfindR output

knitr::kable(head(output_df, 5))
# Out:
# |ID       |Term_Description               | Fold_Enrichment| occurrence|   support| lowest_p| highest_p|Up_regulated                                                                                                                                                                                     |Down_regulated                                       |
# |:--------|:------------------------------|---------------:|----------:|---------:|--------:|---------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------------------------------------------------|
# |hsa04512 |ECM-receptor interaction       |        5.305065|         25| 0.1000000|        0|         0|LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, COL1A2, COL4A1, COL4A2, COL4A5, TNC, FN1, THBS1, ITGB1, ITGA6, SDC1, SDC4, ITGB5, ITGA2, AGRN, DSPP                                                           |ITGA4                                                |
# |hsa04510 |Focal adhesion                 |        3.661016|         25| 0.3953488|        0|         0|ITGB1, ITGB5, ITGA6, ITGA2, MYLK, PARVA, ACTN1, PTK2, CAPN2, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, CAV2, CCND1, MET, PDGFC, VEGFC, JUN, EMP2, EMP1 |ITGA4, CCND2, RAC2, VAV1                             |
# |hsa04151 |PI3K-Akt signaling pathway     |        2.239866|         25| 0.3500000|        0|         0|EPHA2, MET, CCND1, EFNA1, AREG, PDGFC, BDNF, VEGFC, GNG12, ITGA6, ITGA2, ITGB1, ITGB5, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, PTK2, SGK1, MAGI1     |PIK3CG, SYK, GNG7, ITGA4, IL2RB, MYB, PIK3AP1, CCND2 |
# |hsa05222 |Small cell lung cancer         |        3.882896|         25| 0.1707317|        0|         0|CCND1, ITGB1, ITGA6, ITGA2, PTK2, COL4A1, COL4A2, COL4A5, FN1, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2                                                                                                 |E2F2                                                 |
# |hsa05165 |Human papillomavirus infection |        1.832124|         25| 0.2272727|        0|         0|CCND1, ITGA6, ITGA2, ITGB1, ITGB5, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, PTK2, MAGI1, PRKCZ, HES1, FZD6                                            |ITGA4, TNF, CCND2, MFNG, TCF7L2                      |

# %%
# plot fold enrichment results

fold_enrichment_figure <- enrichment_chart(
    result_df = output_df,
    top_terms = 10
) + 
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nTop 10 KEGG Pathway Enrichment Terms\n") +  
ggplot2::theme(
    plot.title = element_text(size = 12, face = "bold", hjust = 0.5),           
    axis.text.y = ggplot2::element_text(size = 12, face = "bold"),              
    legend.title = ggplot2::element_text(size = 14, face = "bold"),             
    legend.text = ggplot2::element_text(size = 14),                             
    #legend.key.size = ggplot2::unit(1, "cm")  
) +
ggplot2::scale_x_continuous(
    breaks = c(2, 3, 4, 5, 6, 7, 8),  # Custom x-axis tick values
    labels = c("2", "3", "4", "5", "6", "7", "8")  # Optional: Custom labels
)

# Save the plot as a PDF file
ggplot2::ggsave(
  filename = paste0(pathfindR_dir, "/KEGG_Fluorouracil/Fold Enrichment (n = 10).pdf"),
  plot = fold_enrichment_figure,             
  width = 10,  
  height = 6   
)

# Display the plot
print(fold_enrichment_figure)
# Out:
# Plotting the enrichment bubble chart
# plot without title

# %%
# cluster enriched terms

pathfindR_output_clustered <- cluster_enriched_terms(output_df, 
                                                     plot_dend = FALSE, 
                                                     plot_clusters_graph = FALSE)

knitr::kable(head(pathfindR_output_clustered, 2))
# Out:
# The maximum average silhouette width was 0.21 for k = 70
# |ID       |Term_Description         | Fold_Enrichment| occurrence|   support| lowest_p| highest_p|Up_regulated                                                                                                                                                                                     |Down_regulated           | Cluster|Status         |
# |:--------|:------------------------|---------------:|----------:|---------:|--------:|---------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------|-------:|:--------------|
# |hsa04512 |ECM-receptor interaction |        5.305065|         25| 0.1000000|        0|         0|LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, COL1A2, COL4A1, COL4A2, COL4A5, TNC, FN1, THBS1, ITGB1, ITGA6, SDC1, SDC4, ITGB5, ITGA2, AGRN, DSPP                                                           |ITGA4                    |       1|Representative |
# |hsa04510 |Focal adhesion           |        3.661016|         25| 0.3953488|        0|         0|ITGB1, ITGB5, ITGA6, ITGA2, MYLK, PARVA, ACTN1, PTK2, CAPN2, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, CAV2, CCND1, MET, PDGFC, VEGFC, JUN, EMP2, EMP1 |ITGA4, CCND2, RAC2, VAV1 |       1|Member         |

# %%
## The representative terms

head(knitr::kable(pathfindR_output_clustered[pathfindR_output_clustered$Status == "Representative", ]), 5)
# Out:
# [1] "|    |ID       |Term_Description                                              | Fold_Enrichment| occurrence|   support|  lowest_p| highest_p|Up_regulated                                                                                                                                      |Down_regulated                                                                                   | Cluster|Status         |"
# [2] "|:---|:--------|:-------------------------------------------------------------|---------------:|----------:|---------:|---------:|---------:|:-------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------------|-------:|:--------------|"
# [3] "|1   |hsa04512 |ECM-receptor interaction                                      |       5.3050649|         25| 0.1000000| 0.0000000| 0.0000000|LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, COL1A2, COL4A1, COL4A2, COL4A5, TNC, FN1, THBS1, ITGB1, ITGA6, SDC1, SDC4, ITGB5, ITGA2, AGRN, DSPP            |ITGA4                                                                                            |       1|Representative |"
# [4] "|6   |hsa04390 |Hippo signaling pathway                                       |       2.7055016|         25| 0.1395349| 0.0000000| 0.0000000|WWC1, FRMD6, YAP1, WWTR1, CTNNA1, CCN2, AREG, CDH1, TEAD4, AJUBA, PRKCZ, SERPINE1, FZD6, CCND1, SNAI2, BMP4, ID1                                  |ITGB2, TCF7L2, CCND2                                                                             |       2|Representative |"
# [5] "|8   |hsa04820 |Cytoskeleton in muscle cells                                  |       4.1218433|         25| 0.1627907| 0.0000000| 0.0000025|SGCE, ITGA6, ITGA2, ITGB1, ITGB5, DSG2, JUP, ATP1B1, LMNA, COL1A2, COL3A1, FN1, THBS1, COL4A1, COL4A2, COL4A5, AGRN, SDC1, SDC2, SDC4, FHL2, TPM1 |ITGA4                                                                                            |       3|Representative |"

# %%
# show output of pathfindR clustered table

head(pathfindR_output_clustered, 3)
# Out:
#   ID       Term_Description           Fold_Enrichment occurrence support
# 1 hsa04512 ECM-receptor interaction   5.305065        25         0.1000000
# 2 hsa04510 Focal adhesion             3.661016        25         0.3953488
# 3 hsa04151 PI3K-Akt signaling pathway 2.239866        25         0.3500000
#   lowest_p     highest_p
# 1 7.832024e-28 3.115309e-18
# 2 1.172572e-24 7.446020e-21
# 3 2.058131e-19 1.335741e-10
#   Up_regulated
# 1 LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, COL1A2, COL4A1, COL4A2, COL4A5, TNC, FN1, THBS1, ITGB1, ITGA6, SDC1, SDC4, ITGB5, ITGA2, AGRN, DSPP
# 2 ITGB1, ITGB5, ITGA6, ITGA2, MYLK, PARVA, ACTN1, PTK2, CAPN2, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, CAV2, CCND1, MET, PDGFC, VEGFC, JUN, EMP2, EMP1
# 3 EPHA2, MET, CCND1, EFNA1, AREG, PDGFC, BDNF, VEGFC, GNG12, ITGA6, ITGA2, ITGB1, ITGB5, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, PTK2, SGK1, MAGI1
#   Down_regulated                                       Cluster Status
# 1 ITGA4                                                1       Representative
# 2 ITGA4, CCND2, RAC2, VAV1                             1       Member
# 3 PIK3CG, SYK, GNG7, ITGA4, IL2RB, MYB, PIK3AP1, CCND2 1       Member

# %%
# plot only selected clusters for better visualization

selected_clusters <- subset(pathfindR_output_clustered, Cluster %in% 1:5)
gg_list <- enrichment_chart(selected_clusters, plot_by_cluster = TRUE)  

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Clustered Bubble Plot.pdf",sep="/"),
  gg_list,             
  width = 10,                                   
  height = 6                                    
)
# Out:
# Plotting the enrichment bubble chart

# %% [markdown]
# # GDSC ###

# %%
# read GDSC expression matrix and sample files

gdsc_experiment_matrix <- read.delim(paste(pathfindR_dir, "GDSC_Experiment_Matrix_DNA_REPi_Fluorouracil_First_Strategy.tsv", sep = "/"))
colnames(gdsc_experiment_matrix)[2:ncol(gdsc_experiment_matrix)] <- sub("^X", "", colnames(gdsc_experiment_matrix)[2:ncol(gdsc_experiment_matrix)])
rownames(gdsc_experiment_matrix) <- gdsc_experiment_matrix$symbol
gdsc_experiment_matrix <- gdsc_experiment_matrix[,-1]
gdsc_experiment_matrix <- as.matrix(gdsc_experiment_matrix)
colnames(gdsc_experiment_matrix) <- as.integer(colnames(gdsc_experiment_matrix))

gdsc_cases_data <- read.delim(paste(pathfindR_dir, "GDSC_DNA_REPi_Fluorouracil_Samples_First_Strategy.tsv", sep ="/"))

filter <- (gdsc_cases_data["Response"] == 0)
cases <- as.character(gdsc_cases_data[filter, "Sample"])

score_matrix <- score_terms(
  enrichment_table = pathfindR_output_clustered,
  exp_mat = gdsc_experiment_matrix,
  cases = cases,
  use_description = TRUE, 
  label_samples = FALSE, 
  case_title = "Resistant", 
  control_title = "Sensitive", 
  low = "#f7797d", # default = "green"
  mid = "#fffde4", # default = "black"
  high = "#1f4037" # default = "red"
)
# Out:
# plot without title

# %%
# plot scores per sample 

hmap <- plot_scores(score_matrix,
                    cases = cases,
                    label_samples = FALSE,
                    case_title = "Resistant", 
                    control_title = "Sensitive", 
                    low = "#f7797d", # default = "green"
                    mid = "#fffde4", # default = "black"
                    high = "#1f4037" # default = "red"
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Scores per Sample Plot (GDSC).pdf",sep="/"),
  hmap,             
  width = 25,                                    
  height = 25                                    
)

# %%
# select some critical enriched terms and export table

terms_significant <- c("ECM-receptor interaction",
                       "Focal adhesion",
                       "PI3K-Akt signaling pathway",
                       "Hippo signaling pathway",
                       "Cytoskeleton in muscle cells",
                       "FoxO signaling pathway",
                       "Adherens junction",
                       "Chemokine signaling pathway",
                       "B cell receptor signaling pathway",
                       "TNF signaling pathway",
                       "Wnt signaling pathway",
                       "Regulation of actin cytoskeleton",
                       "Th1 and Th2 cell differentiation",
                       "Th17 cell differentiation",
                       "Axon guidance",
                       "Protein digestion and absorption",
                       "Estrogen signaling pathway",
                       "IL-17 signaling pathway",
                       "Antigen processing and presentation",
                       "Tight junction",
                       "Ras signaling pathway",
                       "Cytokine-cytokine receptor interaction",
                       "p53 signaling pathway",
                       "MAPK signaling pathway",
                       "JAK-STAT signaling pathway",
                       "HIF-1 signaling pathway",
                       "NF-kappa B signaling pathway",
                       "T cell receptor signaling pathway",
                       "Motor proteins",
                       "Apoptosis",
                       "Chemical carcinogenesis - receptor activation",
                       "Lysosome",
                       "Drug metabolism - other enzymes",
                       "Cellular senescence",
                       "Chemical carcinogenesis - reactive oxygen species",
                       "Chemical carcinogenesis - DNA adducts",
                       "Drug metabolism - cytochrome P450",
                       "Metabolism of xenobiotics by cytochrome P450",
                       "Glutathione metabolism",
                       "Retinol metabolism",
                       "TGF-beta signaling pathway",
                       "Gap junction",
                       "Signaling pathways regulating pluripotency of stem cells",
                       "Cell cycle",
                       "Mitophagy - animal",
                       "Neurotrophin signaling pathway")
save_filtered <- pathfindR_output_clustered[pathfindR_output_clustered$Term_Description %in% terms_significant,]
write.table(save_filtered,
            paste0(pathfindR_dir, "KEGG_Fluorouracil/GDSC_Expression_Mutation_DNA_REPi_Fluorouracil_Selected_Significant_Terms_First_Strategy.tsv"),
            row.names = FALSE,
            quote = FALSE,
            sep = "\t")

# %%
# show top terms

head(save_filtered, 3)
# Out:
#   ID       Term_Description           Fold_Enrichment occurrence support
# 1 hsa04512 ECM-receptor interaction   5.305065        25         0.1000000
# 2 hsa04510 Focal adhesion             3.661016        25         0.3953488
# 3 hsa04151 PI3K-Akt signaling pathway 2.239866        25         0.3500000
#   lowest_p     highest_p
# 1 7.832024e-28 3.115309e-18
# 2 1.172572e-24 7.446020e-21
# 3 2.058131e-19 1.335741e-10
#   Up_regulated
# 1 LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, COL1A2, COL4A1, COL4A2, COL4A5, TNC, FN1, THBS1, ITGB1, ITGA6, SDC1, SDC4, ITGB5, ITGA2, AGRN, DSPP
# 2 ITGB1, ITGB5, ITGA6, ITGA2, MYLK, PARVA, ACTN1, PTK2, CAPN2, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, CAV2, CCND1, MET, PDGFC, VEGFC, JUN, EMP2, EMP1
# 3 EPHA2, MET, CCND1, EFNA1, AREG, PDGFC, BDNF, VEGFC, GNG12, ITGA6, ITGA2, ITGB1, ITGB5, COL1A2, COL4A1, COL4A2, COL4A5, FN1, TNC, LAMA3, LAMB1, LAMB2, LAMC1, LAMC2, THBS1, PTK2, SGK1, MAGI1
#   Down_regulated                                       Cluster Status
# 1 ITGA4                                                1       Representative
# 2 ITGA4, CCND2, RAC2, VAV1                             1       Member
# 3 PIK3CG, SYK, GNG7, ITGA4, IL2RB, MYB, PIK3AP1, CCND2 1       Member

# %%
# plot heatmap and assign it to scores_figure

score_matrix_filtered <- score_terms(
  enrichment_table = save_filtered,
  exp_mat = gdsc_experiment_matrix,
  cases = cases,
  use_description = TRUE, 
  label_samples = FALSE,
  case_title = "Resistant", 
  control_title = "Sensitive", 
  low = "#f7797d", # default = "green"
  mid = "#fffde4", # default = "black"
  high = "#1f4037" # default = "red"
)

scores_figure <- plot_scores(
    score_matrix_filtered,
    cases = cases,
    label_samples = FALSE,
    case_title = "Resistant",  
    control_title = "Sensitive", 
    low = "#f7797d", 
    mid = "#fffde4",  
    high = "#1f4037"  
) +
ggplot2::theme(
    legend.title = ggplot2::element_text(
        size = 12, face = "bold", margin = ggplot2::margin(b = 10)  
    ),
    axis.title.y = ggplot2::element_blank(),          
    axis.text.y = ggplot2::element_text(size = 12, face = "bold"), 
    legend.text = ggplot2::element_text(size = 12),                 
    strip.text = ggplot2::element_text(size = 18, face = "bold")    
)

ggplot2::ggsave(
    paste(pathfindR_dir, "KEGG_Fluorouracil/Scores per Sample Plot (GDSC, selected terms).pdf", sep = "/"),
    scores_figure,
    width = 25,  
    height = 9   
)

scores_figure
# Out:
# plot without title
# plot without title

# %%
# plot term gene heatmap

term_plot <- term_gene_heatmap(output_df, 
                               use_description = TRUE,
                               num_terms = nrow(score_matrix)) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Heatmap") +  
ggplot2::theme(
  plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
  axis.text.x = ggplot2::element_text(size = 9, angle = 60, hjust = 1, vjust = 1, face = "bold"),  
  axis.text.y = ggplot2::element_text(size = 11, face = "bold"),  
  axis.title.x = ggplot2::element_blank(),
  axis.title.y = ggplot2::element_blank(),
  legend.title = ggplot2::element_text(size = 14, face = "bold"),  
  legend.text = ggplot2::element_text(size = 12),                 
  legend.key.size = grid::unit(1.5, "lines")                      
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Heatmap (# of genes)(GDSC).pdf",sep="/"),
  term_plot,             
  width = 40,                                    
  height = 30                                    
)

# %%
# plot term gene heatmap (sorted by p-value)

term_plot_pvalue <- term_gene_heatmap(output_df, 
                               num_terms = nrow(score_matrix),
                               use_description = TRUE,
                               sort_terms_by_p = TRUE) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Heatmap") +  
ggplot2::theme(
  plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
  axis.text.x = ggplot2::element_text(size = 9, angle = 60, hjust = 1, vjust = 1, face = "bold"),  
  axis.text.y = ggplot2::element_text(size = 11, face = "bold"),  
  axis.title.x = ggplot2::element_blank(),
  axis.title.y = ggplot2::element_blank(),
  legend.title = ggplot2::element_text(size = 14, face = "bold"),  
  legend.text = ggplot2::element_text(size = 12),                 
  legend.key.size = grid::unit(1.5, "lines")                      
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Heatmap (p-values)(GDSC).pdf",sep="/"),
  term_plot_pvalue,             
  width = 40,                                    
  height = 30                                    
)

# %%
# plot term gene heatmap with top 10 terms

term_plot_top10 <- term_gene_heatmap(output_df, 
                               use_description = TRUE,
                               num_terms = 10) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Heatmap") +  
ggplot2::theme(
  plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
  axis.text.x = ggplot2::element_text(size = 9, angle = 60, hjust = 1, vjust = 1, face = "bold"),  
  axis.text.y = ggplot2::element_text(size = 11, face = "bold"),  
  axis.title.x = ggplot2::element_blank(),
  axis.title.y = ggplot2::element_blank(),
  legend.title = ggplot2::element_text(size = 14, face = "bold"),  
  legend.text = ggplot2::element_text(size = 12),                 
  legend.key.size = grid::unit(1.5, "lines")                      
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Heatmap (# of genes, top 10)(GDSC).pdf",sep="/"),
  term_plot_top10,             
  width = 18,                                    
  height = 5                                   
)

# %%
# plot term gene heatmap with top 10 terms

term_plot_top10 <- term_gene_heatmap(output_df, 
                               use_description = TRUE,
                               sort_terms_by_p = TRUE,
                               num_terms = 10) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Heatmap") +  
ggplot2::theme(
  plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
  axis.text.x = ggplot2::element_text(size = 9, angle = 60, hjust = 1, vjust = 1, face = "bold"),  
  axis.text.y = ggplot2::element_text(size = 11, face = "bold"),  
  axis.title.x = ggplot2::element_blank(),
  axis.title.y = ggplot2::element_blank(),
  legend.title = ggplot2::element_text(size = 14, face = "bold"),  
  legend.text = ggplot2::element_text(size = 12),                 
  legend.key.size = grid::unit(1.5, "lines")                      
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Heatmap (p-values, top 10)(GDSC).pdf",sep="/"),
  term_plot_top10,             
  width = 18,                                    
  height = 5                                    
)

# %%
# plot term gene heatmap with selected terms

term_plot_filtered <- term_gene_heatmap(save_filtered, 
                                        use_description = TRUE,
                                        num_terms = nrow(score_matrix_filtered)) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Heatmap") +  
ggplot2::theme(
  plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
  axis.text.x = ggplot2::element_text(size = 9, angle = 60, hjust = 1, vjust = 1, face = "bold"),  
  axis.text.y = ggplot2::element_text(size = 11, face = "bold"),  
  axis.title.x = ggplot2::element_blank(),
  axis.title.y = ggplot2::element_blank(),
  legend.title = ggplot2::element_text(size = 14, face = "bold"),  
  legend.text = ggplot2::element_text(size = 12),                 
  legend.key.size = grid::unit(1.5, "lines")                      
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Heatmap (# of genes)(GDSC, selected terms).pdf",sep="/"),
  term_plot_filtered,             
  width = 35,                                    
  height = 9                                    
)

# %%
# plot term gene heatmap with selected terms (sorted by p-values)

term_plot_filtered_pvalue <- term_gene_heatmap(save_filtered, 
                                               use_description = TRUE,
                                               sort_terms_by_p = TRUE,
                                               num_terms = nrow(score_matrix_filtered)) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Heatmap") +  
ggplot2::theme(
  plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
  axis.text.x = ggplot2::element_text(size = 9, angle = 60, hjust = 1, vjust = 1, face = "bold"),  
  axis.text.y = ggplot2::element_text(size = 11, face = "bold"),  
  axis.title.x = ggplot2::element_blank(),
  axis.title.y = ggplot2::element_blank(),
  legend.title = ggplot2::element_text(size = 14, face = "bold"),  
  legend.text = ggplot2::element_text(size = 12),                 
  legend.key.size = grid::unit(1.5, "lines")                      
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Heatmap (p-values)(GDSC, selected terms).pdf",sep="/"),
  term_plot_filtered_pvalue,             
  width = 35,                                    
  height = 9                                    
)

# %%
# plot term gene graph with top 5 terms

p <- term_gene_graph(output_df, 
                     use_description = TRUE,
                     num_terms = 5) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Graph") +  
ggforce::theme_no_axes() + 
ggplot2::theme(
    plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
    plot.subtitle = ggplot2::element_blank(),  
    legend.title = ggplot2::element_text(size = 14, face = "bold"),  
    legend.text = ggplot2::element_text(size = 14)  
) +
ggplot2::scale_size_continuous(name = "# of genes", range = c(4, 8))  # Change legend title

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Graph (n = 5)(GDSC).pdf",sep="/"),
  p,             
  width = 15,                                    
  height = 8                                    
)
# Out:
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.

# %%
# plot term gene graph ith top 10 terms

p <- term_gene_graph(output_df, 
                     use_description = TRUE,
                     num_terms = 10) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Graph") +  
ggforce::theme_no_axes() + 
ggplot2::theme(
    plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
    plot.subtitle = ggplot2::element_blank(),  
    legend.title = ggplot2::element_text(size = 14, face = "bold"),  
    legend.text = ggplot2::element_text(size = 14)  
) +
ggplot2::scale_size_continuous(name = "# of genes", range = c(4, 8))  # Change legend title

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Graph (n = 10)(GDSC).pdf",sep="/"),
  p,             
  width = 15,                                    
  height = 8                                    
)
# Out:
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.

# %%
# plot term gene graph with selected terms (top 5 terms)

p <- term_gene_graph(save_filtered, 
                     use_description = TRUE,
                     num_terms = 5) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Graph") +  
ggforce::theme_no_axes() + 
ggplot2::theme(
    plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
    plot.subtitle = ggplot2::element_blank(),  
    legend.title = ggplot2::element_text(size = 14, face = "bold"),  
    legend.text = ggplot2::element_text(size = 14)  
) +
ggplot2::scale_size_continuous(name = "# of genes", range = c(4, 8))  # Change legend title

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Graph (n = 5)(GDSC, selected terms).pdf",sep="/"),
  p,             
  width = 15,                                    
  height = 8                                    
)
# Out:
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.

# %%
# plot term gene graph with selected terms (top 10 terms)

p <- term_gene_graph(save_filtered, 
                     use_description = TRUE,
                     num_terms = 10) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Graph") +  
ggforce::theme_no_axes() + 
ggplot2::theme(
    plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
    plot.subtitle = ggplot2::element_blank(),  
    legend.title = ggplot2::element_text(size = 14, face = "bold"),  
    legend.text = ggplot2::element_text(size = 14)  
) +
ggplot2::scale_size_continuous(name = "# of genes", range = c(4, 8))  # Change legend title

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Graph (n = 10)(GDSC, selected terms).pdf",sep="/"),
  p,             
  width = 15,                                    
  height = 8                                    
)
# Out:
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.

# %%
# plot term gene graph with selected terms 

term_gene_figure <- term_gene_graph(save_filtered, 
                     use_description = TRUE,
                     num_terms = nrow(save_filtered)) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Term-Gene Graph") +  
ggforce::theme_no_axes() + 
ggplot2::theme(
    plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
    plot.subtitle = ggplot2::element_blank(),  
    legend.title = ggplot2::element_text(size = 14, face = "bold"),  
    legend.text = ggplot2::element_text(size = 14)  
) +
ggplot2::scale_size_continuous(name = "# of genes", range = c(4, 8))  # Change legend title

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Term Gene Graph (GDSC, selected terms).pdf",sep="/"),
  p,             
  width = 20,                                    
  height = 11                                    
)
# Out:
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.

# %%
# upset plot with top 10 terms

upset_plot <- UpSet_plot(output_df,
                         num_terms = 10) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Upset plot\n") +
ggplot2::theme(
    plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
    plot.subtitle = ggplot2::element_blank(),  
    legend.title = ggplot2::element_text(size = 14, face = "bold"),  
    legend.text = ggplot2::element_text(size = 14)  
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Upset Plot (n = 10)(GDSC).pdf",sep="/"),
  upset_plot,             
  width = 18,                                    
  height = 15                                    
)

# %%
# upset plot with selected terms (top 10 terms)

upset_plot <- UpSet_plot(save_filtered,
                         num_terms = 10) +
ggplot2::ggtitle("DNA replication inhibitors (5-Fluorouracil)\nKEGG Pathways, Upset plot\n") +
ggplot2::theme(
    plot.title = ggplot2::element_text(size = 14, face = "bold", hjust = 0.5),  
    plot.subtitle = ggplot2::element_blank(),  
    legend.title = ggplot2::element_text(size = 14, face = "bold"),  
    legend.text = ggplot2::element_text(size = 14)  
)

ggplot2::ggsave(
  paste(pathfindR_dir,"KEGG_Fluorouracil/Upset Plot (n = 10)(GDSC, selected terms).pdf",sep="/"),
  upset_plot,             
  width = 18,                                    
  height = 15                                    
)

# %%
# read GDSC cell line details

gdsc_sample_info <- read_excel(paste0(gdsc_dir, "/GDSC_Cell_Lines_Details.xlsx"))
gdsc_sample_info <- gdsc_sample_info[,c("Sample Name",
                                        "COSMIC identifier",
                                        "GDSC\r\nTissue descriptor 1")]
head(gdsc_sample_info)
# Out:
#   Sample Name COSMIC identifier GDSC\r\nTissue descriptor 1
# 1 A253         906794           aero_dig_tract
# 2 BB30-HNC     753531           aero_dig_tract
# 3 BB49-HNC     753532           aero_dig_tract
# 4 BHY          753535           aero_dig_tract
# 5 BICR10      1290724           aero_dig_tract
# 6 BICR22      1240121           aero_dig_tract

# %%
# merge GDSC cell line detail table with GDSC experiment matrix table

gdsc_experiment_mat <- t(gdsc_experiment_matrix)
gdsc_experiment_mat <- cbind(rownames(gdsc_experiment_mat),gdsc_experiment_mat)
colnames(gdsc_experiment_mat)[1] <- "COSMIC identifier"

gdsc_experiment_mat_tissue <- merge(gdsc_sample_info,
                                    gdsc_experiment_mat,
                                    by= "COSMIC identifier")
head(gdsc_experiment_mat_tissue)
# Out:
#   COSMIC identifier Sample Name GDSC\r\nTissue descriptor 1 ACTN1
# 1 683665            MC-CAR      myeloma                     -1.32067119578754
# 2 683667            PFSK-1      nervous_system              -0.393652444116975
# 3 684052            A673        soft_tissue                 0.167084501503202
# 4 684055            ES3         bone                        -1.1038452262866
# 5 684057            ES5         bone                        -1.26990038318732
# 6 684059            ES7         bone                        -0.371793517964657
#   ADA                 ADM                ADORA2B             AEBP1
# 1 1.4366810172981     -1.35261677480684  -1.43983243533375   0.748239562165711
# 2 0.964925500402852   -0.590050048839158 0.360853799002762   1.6611710693668
# 3 0.678942670968474   -0.787479554084742 -0.656081027135807  1.12202951423544
# 4 -0.0722572533106381 -1.11950681879136  -1.02385699993337   0.282148889380843
# 5 0.564012775113484   -1.08596842095866  -0.0469790609896668 1.12686701848256
# 6 -0.0863264421063415 0.445046012465862  -0.756751456908886  1.54082597523846
#   AHR                ALDH1A1            ⋯ FBXO43
# 1 -0.758333894521698 -0.207316566048553 ⋯ 0.931981210664494
# 2 -0.763440033790151 -0.701968917431721 ⋯ -0.44402655318849
# 3 -0.550526388201367 0.146356000975374  ⋯ 1.25949434720171
# 4 -1.0445013711902   0.125478689373388  ⋯ 0.796938121506103
# 5 -0.952683105049508 0.705235486713586  ⋯ 1.46706885116269
# 6 -0.485287972821327 0.977265233840721  ⋯ -0.0479753183867866
#   ARMH1               TSPAN33            TUBB2B             SERINC2
# 1 1.28365454900553    2.14118278477417   -0.739531258193347 0.533177678695854
# 2 -0.348592213217557  -0.506072487173253 -0.533978452011763 1.3938444071982
# 3 -0.285981996623255  -0.652072539258054 1.31371201152387   -1.30341495045216
# 4 -0.335323526502265  0.262468540392032  1.63006070861982   0.562892360502154
# 5 -0.0447733022586652 0.438296126520666  1.44099962937408   -0.1171584763177
# 6 -0.189470097140401  -0.158397816941313 1.45409941768693   -1.152882351803
#   AMIGO2             TBC1D10C            NRROS              AGRN
# 1 -1.30134768878068  2.41079505192691    2.0528630383186    -0.291445503768294
# 2 -0.376906733077427 -0.0966566286083775 0.321044679570113  0.340245464471371
# 3 -0.568971088724495 -0.404976276951514  -0.539120930986954 0.0961850185679424
# 4 -0.98313431501998  -0.467293630076887  -0.308751195374171 -0.416810058672061
# 5 -1.05125309417583  -0.432690578622858  -0.439420340391963 0.20342977520573
# 6 -0.278944885841798 -0.351139782637541  -0.586328723950001 -0.164723411620455
#   GPX8
# 1 -1.40608036129727
# 2 0.672949469211017
# 3 0.803629292757566
# 4 0.681942627930971
# 5 0.315107681652811
# 6 0.623353462460017

# %%
# find number of tissue types

sort(table(gdsc_experiment_mat_tissue["GDSC\r\nTissue descriptor 1"]),
     decreasing = TRUE)
# Out:
# GDSC
# Tissue descriptor 1
#        lung_NSCLC urogenital_system          leukemia    aero_dig_tract
#                86                78                63                59
#          lymphoma    nervous_system              skin         lung_SCLC
#                57                50                47                46
#            breast   large_intestine  digestive_system              bone
#                44                38                37                34
#     neuroblastoma          pancreas            kidney              lung
#                28                25                18                15
#       soft_tissue           myeloma           thyroid
#                14                13                12

# %%
# merge GDSC sample info with GDSC cases 

gdsc_cases_info <- merge(gdsc_sample_info,
                         gdsc_cases_data,
                         by.x = "COSMIC identifier",
                         by.y = "Sample")

head(gdsc_cases_info)
# Out:
#   COSMIC identifier Sample Name GDSC\r\nTissue descriptor 1 Response
# 1 683665            MC-CAR      myeloma                     1
# 2 683667            PFSK-1      nervous_system              0
# 3 684052            A673        soft_tissue                 0
# 4 684055            ES3         bone                        0
# 5 684057            ES5         bone                        0
# 6 684059            ES7         bone                        1

# %%
# 5-Fluorouracil sensitive cell lines as to their tissue descriptor in GDSC

sen <- sort(table(gdsc_cases_info[gdsc_cases_info["Response"] == 1,3]),
       decreasing = TRUE)
sen
# Out:
#          leukemia          lymphoma     neuroblastoma urogenital_system
#                25                19                 7                 6
#        lung_NSCLC    aero_dig_tract              bone   large_intestine
#                 5                 4                 3                 3
#           myeloma          pancreas            breast            kidney
#                 3                 2                 1                 1
#         lung_SCLC              skin       soft_tissue
#                 1                 1                 1

# %%
# 5-Fluorouracil resistant cell lines as to their tissue descriptor in GDSC

res<- sort(table(gdsc_cases_info[gdsc_cases_info["Response"] == 0,3]),
      decreasing = TRUE)
res
# Out:
#        lung_NSCLC urogenital_system    aero_dig_tract    nervous_system
#                81                72                55                50
#              skin         lung_SCLC            breast          leukemia
#                46                45                43                38
#          lymphoma  digestive_system   large_intestine              bone
#                38                37                35                31
#          pancreas     neuroblastoma            kidney              lung
#                23                21                17                15
#       soft_tissue           thyroid           myeloma
#                13                12                10

# %%
# Count table of resistant and sensitive cell lines to 5-Fluorouracil in GDSC

aligned_vector2 <- sen[match(names(res), names(sen))]
combined_df <- cbind(res, aligned_vector2)
colnames(combined_df) <- c("Resistant","Sensitive")
combined_df <- as.data.frame(combined_df)
combined_df <- combined_df[order(combined_df$Sensitive, decreasing = TRUE),]
combined_df
# Out:
#                   Resistant Sensitive
# leukemia          38        25
# lymphoma          38        19
# neuroblastoma     21         7
# urogenital_system 72         6
# lung_NSCLC        81         5
# aero_dig_tract    55         4
# large_intestine   35         3
# bone              31         3
# myeloma           10         3
# pancreas          23         2
# skin              46         1
# lung_SCLC         45         1
# breast            43         1
# kidney            17         1
# soft_tissue       13         1
# nervous_system    50        NA
# digestive_system  37        NA
# lung              15        NA
# thyroid           12        NA

# %%
paste("There are",sum(combined_df$Resistant),"5-Fluorouracil resistant cell lines in GDSC")
paste("There are",sum(na.omit(combined_df$Sensitive)),"5-Fluorouracil sensitive cell lines in GDSC")
paste("Sen/(Sen + Res):", round(sum(na.omit(combined_df$Sensitive))/(sum(na.omit(combined_df$Sensitive)) +sum(combined_df$Resistant)),2))
# Out:
# [1] "There are 682 5-Fluorouracil resistant cell lines in GDSC"
# [1] "There are 82 5-Fluorouracil sensitive cell lines in GDSC"
# [1] "Sen/(Sen + Res): 0.11"
